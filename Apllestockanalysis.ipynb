# %%
pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      -- ------------------------------------- 0.2/3.0 MB 5.9 MB/s eta 0:00:01
#      ----- ---------------------------------- 0.4/3.0 MB 4.9 MB/s eta 0:00:01
#      -------- ------------------------------- 0.6/3.0 MB 4.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.8/3.0 MB 4.9 MB/s eta 0:00:01
#      -------------- ------------------------- 1.1/3.0 MB 4.9 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.3/3.0 MB 4.9 MB/s eta 0:00:01
#      -------------------- ------------------- 1.5/3.0 MB 4.8 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.7/3.0 MB 4.8 MB/s eta 0:00:01
#      -------------------------- ------------- 1.9/3.0 MB 4.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.2/3.0 MB 4.7 MB/s eta 0:00:01
#      -------------------------------- ------- 2.4/3.0 MB 4.8 MB/s eta 0:00:01
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      --------- ----------------------------- 41.0/165.9 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.8 MB 7.0 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.8 MB 4.7 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/7.8 MB 4.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.8 MB 4.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.8 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.8 MB 4.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.8 MB 4.1 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.8 MB 4.1 MB/s eta 0:00:02
# ...

# %%
#By using yfinance day to day stock values can be used
import yfinance as yf
import pandas as pd

# %%
#considering stocks of apple,for understanding I have taken current years data
ticker='AAPL'
data=yf.download(ticker,period='ytd')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#printing the head of the data
print("Head of the data")
data.head()
# Out:
# Head of the data
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  184.938217
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  183.553482
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.222321
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.495087
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  184.858521
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500

# %%
#printing tail of the data
print("Tail of the data")
data.tail()
# Out:
# Tail of the data
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-08-26  226.759995  227.279999  223.889999  227.179993  227.179993
# 2024-08-27  226.000000  228.850006  224.889999  228.029999  228.029999
# 2024-08-28  227.919998  229.860001  225.679993  226.490005  226.490005
# 2024-08-29  230.100006  232.919998  228.880005  229.789993  229.789993
# 2024-08-30  230.190002  230.399994  227.479996  229.000000  229.000000
#
#               Volume
# Date
# 2024-08-26  30602200
# 2024-08-27  35934600
# 2024-08-28  38052200
# 2024-08-29  51906300
# 2024-08-30  52958500

# %%
#printing infromation such as missing values,number of rows,colums etc from the data
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2024-01-02 to 2024-08-30
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          168 non-null    float64
#  1   High          168 non-null    float64
#  2   Low           168 non-null    float64
#  3   Close         168 non-null    float64
#  4   Adj Close     168 non-null    float64
#  5   Volume        168 non-null    int64
#  6   Daily return  167 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 10.5 KB
# None

# %%
#basic statistics of each colum
print(data.describe())
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  168.000000  168.000000  168.000000  168.000000  168.000000
# mean   194.252380  196.172500  192.514821  194.389583  194.020255
# std     20.554547   20.896348   20.132660   20.590587   20.712093
# min    165.350006  166.399994  164.080002  165.000000  164.585999
# 25%    176.825001  178.592499  174.869999  178.139999  177.693027
# 50%    188.735001  190.285004  187.360001  188.740005  188.146545
# 75%    214.119995  216.962498  211.932499  214.252502  214.004791
# max    236.479996  237.229996  233.089996  234.820007  234.548523
#
#              Volume
# count  1.680000e+02
# mean   6.168811e+07
# std    2.820869e+07
# min    3.029900e+07
# 25%    4.596918e+07
# 50%    5.353515e+07
# 75%    6.862602e+07
# max    2.464214e+08

# %%
#checking null values
print(data.isnull().sum())
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#visulaizing the data
#Opening prize 
import matplotlib.pyplot as plt
sp=data['Open'].plot(figsize=(14,7),title='Opening prize of Apple Stock',grid=True)
sp.set_xlabel('Start date')
sp.set_ylabel('Prize(USD)')
plt.show()

# %%
#Visualizing the close prize 
ep=data['Close'].plot(figsize=(14,7),title='Closing prize of Apple Stock',grid=True)
ep.set_xlabel("Date")
ep.set_ylabel("Prize(USD)")
plt.show()

# %%
#analyzing the volume traded
v=data['Volume'].plot(kind='bar',figsize=(14,7),grid=True,title='Volume traded')
v.set_xlabel("Date")
v.set_ylabel("Quantity")
plt.show()

# %%
#analyzing percentage change in daily returns
data['Daily return']=data['Close'].pct_change()
dr=data['Daily return'].plot(kind='hist',bins=50,title='Daily returns')
plt.show()

# %%
pip install sesborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sesborn (from versions: none)
# ERROR: No matching distribution found for sesborn
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Correlation analysis - undestanding relationship between differt columns
import seaborn as sns
cm=data.corr()
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,cmap='coolwarm')
plt.title("Correlation matrix")
plt.show()

# %%
#identifying outliers
plt.figure(figsize=(10,7))
sns.boxplot(x=data['Close'])
plt.show()

# %%
#monthly resampling
monthly_data=data['Close'].resample('M').mean()
monthly_data.plot(kind='bar',color='red',title='Monthly Resampling',xlabel='Month',ylabel='Prize')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3124\4255399722.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data=data['Close'].resample('M').mean()

# %%
#weekly resampling
weekly_data=data['Close'].resample('W').mean()
weekly_data.plot(kind='bar',color='green',title='Weekly resampling',xlabel='Week',ylabel='Prize')
plt.show()
